# %%
django-admin startproject landeskunde # Create a new Django project named 'landeskunde'

# %% [markdown]
# ### struktur
#
# landeskunde_backend/
# ├── landeskunde/          ← Hauptprojektordner (automatisch erstellt)
# │   ├── __init__.py
# │   ├── asgi.py
# │   ├── settings.py       ← wichtigste Datei: hier steht die Konfiguration
# │   ├── urls.py
# │   └── wsgi.py
# └── manage.py             ← Haupt-Steuerdatei

# %%
# PostgreSQL/PostGIS-Datenbank eintragen 
# suche nach 'DATABASES' in settings.py 

DATABASES = {
    'default': {
        'ENGINE': 'django.db.backends.sqlite3',
        'NAME': BASE_DIR / "db.sqlite3",
    }
}
# und ersetze den Block durch Folgendes:
DATABASES = {
    'default': {
        'ENGINE': 'django.contrib.gis.db.backends.postgis',  # wichtig: PostGIS-Backend
        'NAME': 'deine_datenbank',      # z.B. landeskunde
        'USER': 'dein_postgres_user',   # z.B. postgres
        'PASSWORD': 'dein_passwort',    # dein Passwort
        'HOST': 'localhost',
        'PORT': '5432',
    }
}

-->

DATABASES = {
    'default': {
        'ENGINE': 'django.contrib.gis.db.backends.postgis',  # wichtig: PostGIS-Backend
        'NAME': 'landeskunde',      # z.B. landeskunde
        'USER': 'postgres',   # z.B. postgres
        'PASSWORD': 'password',    # dein Passwort
        'HOST': 'localhost',
        'PORT': '5432',
    }
}

# %%
# Projektpfad + umgebung aktivieren

'''

cd C:\Users\daniil\Desktop\proj_landeskunde\landeskunde_backend\
venv\Scripts\activate

cd C:\Users\daniil\Desktop\proj_landeskunde\landeskunde_backend\landeskunde

'''

# %%
# app erstellen:

python manage.py startapp api
